dribbles_percent%2Ctouch_in_box_avg%2Cprogressive_run_avg%2Cpasses_avg%2Caccurate_passes_percent%2Cforward_passes_avg%2Csuccessful_forward_passes_percent%2Cback_passes_avg%2Csuccessful_back_passes_percent%2Cvertical_passes_avg%2Csuccessful_vertical_passes_percent%2Cshort_medium_pass_avg%2Caccurate_short_medium_pass_percent%2Clong_passes_avg%2Csuccessful_long_passes_percent%2Caverage_pass_length%2Caverage_long_pass_length%2Cxg_assist_avg%2Cpre_assist_avg%2Cpre_pre_assist_avg%2Csmart_passes_avg%2Caccurate_smart_passes_percent%2Ckey_passes_avg%2Cpasses_to_final_third_avg%2Caccurate_passes_to_final_third_percent%2Cpass_to_penalty_area_avg%2Caccurate_pass_to_penalty_area_percent%2Cthrough_passes_avg%2Csuccessful_through_passes_percent%2Cdeep_completed_pass_avg%2Csuccessful_deep_completed_pass_percent%2Cdeep_completed_cross_avg%2Csuccessful_deep_completed_cross_percent%2Cprogressive_pass_avg%2Cfree_kicks_taken_avg%2Cdirect_free_kicks_taken_avg%2Cdirect_free_kicks_on_target_percent%2Ccorners_taken_avg%2Cpenalties_taken%2Cpenalties_conversion_percent&token=d3e1d965361987405f6cdd29eec8a6c15fa8e43c&groupId=1110432&subgroupId=163958

# %%
import json
import requests
from pandas.io.json import json_normalize
import pandas as pd
import re

from bs4 import BeautifulSoup

# %%
l = []
for i in range(160):
    url= f'https://searchapi.wyscout.com/api/v1/search/results.json?search%5Btime_frame%5D=default&search%5Bpositions%5D%5B%5D=LB&search%5Bpositions%5D%5B%5D=CB&search%5Bpositions%5D%5B%5D=LCB&search%5Bpositions%5D%5B%5D=RCB&search%5Bpositions%5D%5B%5D=LCB3&search%5Bpositions%5D%5B%5D=RCB3&search%5Bpositions%5D%5B%5D=RB&search%5Bpositions%5D%5B%5D=RB5&search%5Bpositions%5D%5B%5D=RWB&search%5Bpositions%5D%5B%5D=RW&search%5Bpositions%5D%5B%5D=RAMF&search%5Bpositions%5D%5B%5D=DMF&search%5Bpositions%5D%5B%5D=LDMF&search%5Bpositions%5D%5B%5D=RDMF&search%5Bpositions%5D%5B%5D=LCMF&search%5Bpositions%5D%5B%5D=RCMF&search%5Bpositions%5D%5B%5D=LCMF3&search%5Bpositions%5D%5B%5D=RCMF3&search%5Bpositions%5D%5B%5D=LB5&search%5Bpositions%5D%5B%5D=LWB&search%5Bpositions%5D%5B%5D=LW&search%5Bpositions%5D%5B%5D=LAMF&search%5Bpositions%5D%5B%5D=AMF&search%5Bpositions%5D%5B%5D=LWF&search%5Bpositions%5D%5B%5D=CF&search%5Bpositions%5D%5B%5D=SS&search%5Bpositions%5D%5B%5D=RWF&search%5Bcompetition_ids%5D%5B%5D=155&search%5Bcompetition_ids%5D%5B%5D=163&search%5Bcompetition_ids%5D%5B%5D=165&search%5Bcompetition_ids%5D%5B%5D=91&search%5Bcompetition_ids%5D%5B%5D=69&search%5Bcompetition_ids%5D%5B%5D=158&search%5Bcompetition_ids%5D%5B%5D=157&search%5Bcompetition_ids%5D%5B%5D=90&search%5Bcompetition_ids%5D%5B%5D=162&search%5Byouth_stats%5D=false&count=30&page={i}&sort=market_value+desc&language=es&columns=name%2Cid%2Cimage%2Ccurrent_team_logo%2Ccurrent_team_color%2Cbirth_country_name%2Cpassport_country_names%2Ccurrent_team_name%2Cmarket_value%2Ctotal_matches%2Cminutes_on_field%2Cpositions%2Cage%2Ccontract_expires%2Cgoals%2Cxg_shot%2Cassists%2Cxg_assist%2Cfoot%2Cheight%2Cweight%2Con_loan%2Csuccessful_defensive_actions_avg%2Cdefensive_duels_avg%2Cdefensive_duels_won%2Caerial_duels_avg%2Caerial_duels_won%2Ctackle_avg%2Cpossession_adjusted_tackle%2Csuccessful_tackle_percent%2Cshot_block_avg%2Cinterceptions_avg%2Cpossession_adjusted_interceptions%2Cfouls_avg%2Cyellow_cards%2Cyellow_cards_avg%2Cred_cards%2Cred_cards_avg%2Csuccessful_attacking_actions_avg%2Cgoals_avg%2Cnon_penalty_goal%2Cnon_penalty_goal_avg%2Cxg_shot_avg%2Chead_goals%2Chead_goals_avg%2Cshots%2Cshots_avg%2Cshots_on_target_percent%2Cgoal_conversion_percent%2Cassists_avg%2Ccrosses_avg%2Caccurate_crosses_percent%2Ccross_from_left_avg%2Csuccessful_cross_from_left_percent%2Ccross_from_right_avg%2Csuccessful_cross_from_right_percent%2Ccross_to_goalie_box_avg%2Cdribbles_avg%2Csuccessful_dribbles_percent%2Ctouch_in_box_avg%2Cprogressive_run_avg%2Cpasses_avg%2Caccurate_passes_percent%2Cforward_passes_avg%2Csuccessful_forward_passes_percent%2Cback_passes_avg%2Csuccessful_back_passes_percent%2Cvertical_passes_avg%2Csuccessful_vertical_passes_percent%2Cshort_medium_pass_avg%2Caccurate_short_medium_pass_percent%2Clong_passes_avg%2Csuccessful_long_passes_percent%2Caverage_pass_length%2Caverage_long_pass_length%2Cxg_assist_avg%2Cpre_assist_avg%2Cpre_pre_assist_avg%2Csmart_passes_avg%2Caccurate_smart_passes_percent%2Ckey_passes_avg%2Cpasses_to_final_third_avg%2Caccurate_passes_to_final_third_percent%2Cpass_to_penalty_area_avg%2Caccurate_pass_to_penalty_area_percent%2Cthrough_passes_avg%2Csuccessful_through_passes_percent%2Cdeep_completed_pass_avg%2Csuccessful_deep_completed_pass_percent%2Cdeep_completed_cross_avg%2Csuccessful_deep_completed_cross_percent%2Cprogressive_pass_avg%2Cfree_kicks_taken_avg%2Cdirect_free_kicks_taken_avg%2Cdirect_free_kicks_on_target_percent%2Ccorners_taken_avg%2Cpenalties_taken%2Cpenalties_conversion_percent&token=d3e1d965361987405f6cdd29eec8a6c15fa8e43c&groupId=1110432&subgroupId=163958'
    headers = {"User-Agent":"Mozilla/5.0"}
    response = requests.get(url, headers=headers).json() 
    flattened_data = json_normalize(response['players'])
    l.append(flattened_data)
dataframe = pd.concat(l)
dataframe = dataframe.reset_index()
dataframe.head(40)
# Out:
#     index  accurate_crosses_percent  accurate_pass_to_penalty_area_percent  \
# 0       0                     33.33                                  56.25
# 1       1                     33.33                                  41.67
# 2       2                     26.67                                  60.00
# 3       3                     30.00                                  65.14
# 4       4                     50.00                                  45.45
# 5       5                     35.29                                  68.42
# 6       6                       NaN                                    NaN
# 7       7                     18.18                                  54.55
# 8       8                     50.00                                  54.05
# 9       9                     39.29                                  52.78
# 10     10                     44.00                                  61.90
# ...

# %%
# Liga Mx, venezolana, ecuatoriana, colombiana, boliviana, peruana, paraguaya, chilena, uruguaya. 
dataframe.to_csv('wyscout_ligas_sudamericanas_agregado.csv', index=False)

# %%
dataframe.shape
# Out:
# (4800, 111)

# %%
dataframe.full_name[:20]
# Out:
# 0                    Diego Lainez Leyva
# 1          Edson Omar Álvarez Velázquez
# 2              Maximiliano Eduardo Meza
# 3        Rodolfo Gilbert Pizarro Thomas
# 4         Carlos Joel Salcedo Hernández
# 5                       Guido Rodríguez
# 6                       Vincent Janssen
# 7                  Guido Hernán Pizarro
# 8               Orbelín Pineda Alvarado
# 9          Víctor Alfonso Guzmán Guzmán
# 10            Andrés Mateus Uribe Villa
# 11    Roberto Carlos Alvarado Hernández
# 12                    Iván José Marcone
# 13           Rogelio Gabriel Funes Mori
# 14        Nicolás Ignacio Castillo Mora
# 15                 Bruno Amílcar Valdez
# 16               Brian Leonel Fernández
# 17                    Julio César Furch
# 18        Cecilio Andrés Domínguez Ruiz
# 19        Javier Ignacio Aquino Carmona
# Name: full_name, dtype: object

# %% [markdown]
# Web Scrapping Continente Americano
#
# Liga Mx, venezolana, ecuatoriana, colombiana, boliviana, peruana, paraguaya, chilena, uruguaya, panameña, MLS, Brasileña, Segunda División Brasileña, Argentina, Segunda División Española
#
# https://searchapi.wyscout.com/api/v1/search/results.json?search%5Btime_frame%5D=default&search%5Bpositions%5D%5B%5D=CB&search%5Bpositions%5D%5B%5D=LCB&search%5Bpositions%5D%5B%5D=RCB&search%5Bpositions%5D%5B%5D=LCB3&search%5Bpositions%5D%5B%5D=RCB3&search%5Bpositions%5D%5B%5D=RB&search%5Bpositions%5D%5B%5D=LB&search%5Bpositions%5D%5B%5D=LB5&search%5Bpositions%5D%5B%5D=LWB&search%5Bpositions%5D%5B%5D=LW&search%5Bpositions%5D%5B%5D=LAMF&search%5Bpositions%5D%5B%5D=DMF&search%5Bpositions%5D%5B%5D=LDMF&search%5Bpositions%5D%5B%5D=RDMF&search%5Bpositions%5D%5B%5D=LCMF&search%5Bpositions%5D%5B%5D=RCMF&search%5Bpositions%5D%5B%5D=LCMF3&search%5Bpositions%5D%5B%5D=RCMF3&search%5Bpositions%5D%5B%5D=RB5&search%5Bpositions%5D%5B%5D=RWB&search%5Bpositions%5D%5B%5D=RW&search%5Bpositions%5D%5B%5D=RAMF&search%5Bpositions%5D%5B%5D=AMF&search%5Bpositions%5D%5B%5D=CF&search%5Bpositions%5D%5B%5D=SS&search%5Bpositions%5D%5B%5D=RWF&search%5Bpositions%5D%5B%5D=LWF&search%5Bcompetition_ids%5D%5B%5D=155&search%5Bcompetition_ids%5D%5B%5D=33&search%5Bcompetition_ids%5D%5B%5D=525&search%5Bcompetition_ids%5D%5B%5D=315&search%5Bcompetition_ids%5D%5B%5D=163&search%5Bcompetition_ids%5D%5B%5D=165&search%5Bcompetition_ids%5D%5B%5D=91&search%5Bcompetition_ids%5D%5B%5D=69&search%5Bcompetition_ids%5D%5B%5D=158&search%5Bcompetition_ids%5D%5B%5D=162&search%5Bcompetition_ids%5D%5B%5D=87&search%5Bcompetition_ids%5D%5B%5D=231&search%5Bcompetition_ids%5D%5B%5D=157&search%5Bcompetition_ids%5D%5B%5D=90&search%5Byouth_stats%5D=false&count=30&page=1&sort=market_value+desc&language=es&columns=name%2Cid%2Cimage%2Ccurrent_team_logo%2Ccurrent_team_color%2Cbirth_country_name%2Cpassport_country_names%2Ccurrent_team_name%2Cmarket_value%2Ctotal_matches%2Cminutes_on_field%2Cpositions%2Cage%2Ccontract_expires%2Cgoals%2Cxg_shot%2Cassists%2Cxg_assist%2Cfoot%2Cheight%2Cweight%2Con_loan%2Csuccessful_defensive_actions_avg%2Cdefensive_duels_avg%2Cdefensive_duels_won%2Caerial_duels_avg%2Caerial_duels_won%2Ctackle_avg%2Cpossession_adjusted_tackle%2Csuccessful_tackle_percent%2Cshot_block_avg%2Cinterceptions_avg%2Cpossession_adjusted_interceptions%2Cfouls_avg%2Cyellow_cards%2Cyellow_cards_avg%2Cred_cards%2Cred_cards_avg%2Csuccessful_attacking_actions_avg%2Cgoals_avg%2Cnon_penalty_goal%2Cnon_penalty_goal_avg%2Cxg_shot_avg%2Chead_goals%2Chead_goals_avg%2Cshots%2Cshots_avg%2Cshots_on_target_percent%2Cgoal_conversion_percent%2Cassists_avg%2Ccrosses_avg%2Caccurate_crosses_percent%2Ccross_from_left_avg%2Csuccessful_cross_from_left_percent%2Ccross_from_right_avg%2Csuccessful_cross_from_right_percent%2Ccross_to_goalie_box_avg%2Cdribbles_avg%2Csuccessful_dribbles_percent%2Ctouch_in_box_avg%2Cprogressive_run_avg%2Cpasses_avg%2Caccurate_passes_percent%2Cforward_passes_avg%2Csuccessful_forward_passes_percent%2Cback_passes_avg%2Csuccessful_back_passes_percent%2Cvertical_passes_avg%2Csuccessful_vertical_passes_percent%2Cshort_medium_pass_avg%2Caccurate_short_medium_pass_percent%2Clong_passes_avg%2Csuccessful_long_passes_percent%2Caverage_pass_length%2Caverage_long_pass_length%2Cxg_assist_avg%2Cpre_assist_avg%2Cpre_pre_assist_avg%2Csmart_passes_avg%2Caccurate_smart_passes_percent%2Ckey_passes_avg%2Cpasses_to_final_third_avg%2Caccurate_passes_to_final_third_percent%2Cpass_to_penalty_area_avg%2Caccurate_pass_to_penalty_area_percent%2Cthrough_passes_avg%2Csuccessful_through_passes_percent%2Cdeep_completed_pass_avg%2Csuccessful_deep_completed_pass_percent%2Cdeep_completed_cross_avg%2Csuccessful_deep_completed_cross_percent%2Cprogressive_pass_avg%2Cfree_kicks_taken_avg%2Cdirect_free_kicks_taken_avg%2Cdirect_free_kicks_on_target_percent%2Ccorners_taken_avg%2Cpenalties_taken%2Cpenalties_conversion_percent&token=a5ddeadeac0e29a4f83058713036c352fecedd87&groupId=1110432&subgroupId=163958

# %%
lista = []
for i in range(269):
ses_avg%2Caccurate_crosses_percent%2Ccross_from_left_avg%2Csuccessful_cross_from_left_percent%2Ccross_from_right_avg%2Csuccessful_cross_from_right_percent%2Ccross_to_goalie_box_avg%2Cdribbles_avg%2Csuccessful_dribbles_percent%2Ctouch_in_box_avg%2Cprogressive_run_avg%2Cpasses_avg%2Caccurate_passes_percent%2Cforward_passes_avg%2Csuccessful_forward_passes_percent%2Cback_passes_avg%2Csuccessful_back_passes_percent%2Cvertical_passes_avg%2Csuccessful_vertical_passes_percent%2Cshort_medium_pass_avg%2Caccurate_short_medium_pass_percent%2Clong_passes_avg%2Csuccessful_long_passes_percent%2Caverage_pass_length%2Caverage_long_pass_length%2Cxg_assist_avg%2Cpre_assist_avg%2Cpre_pre_assist_avg%2Csmart_passes_avg%2Caccurate_smart_passes_percent%2Ckey_passes_avg%2Cpasses_to_final_third_avg%2Caccurate_passes_to_final_third_percent%2Cpass_to_penalty_area_avg%2Caccurate_pass_to_penalty_area_percent%2Cthrough_passes_avg%2Csuccessful_through_passes_percent%2Cdeep_completed_pass_avg%2Csuccessful_deep_completed_pass_percent%2Cdeep_completed_cross_avg%2Csuccessful_deep_completed_cross_percent%2Cprogressive_pass_avg%2Cfree_kicks_taken_avg%2Cdirect_free_kicks_taken_avg%2Cdirect_free_kicks_on_target_percent%2Ccorners_taken_avg%2Cpenalties_taken%2Cpenalties_conversion_percent&token=a5ddeadeac0e29a4f83058713036c352fecedd87&groupId=1110432&subgroupId=163958'
    headers = {"User-Agent":"Mozilla/5.0"}
    resp = requests.get(url, headers=headers).json() 
    data = json_normalize(resp['players'])
    lista.append(data)
full_dataframe = pd.concat(lista)
full_dataframe = full_dataframe.reset_index()
full_dataframe.head()
# Out:
#    index  accurate_crosses_percent  accurate_pass_to_penalty_area_percent  \
# 0      0                     28.57                                  59.83
# 1      1                     22.62                                  59.09
# 2      2                     24.24                                  45.90
# 3      3                     23.26                                  57.14
# 4      4                     52.94                                  56.25
#
#    accurate_passes_percent  accurate_passes_to_final_third_percent  \
# 0                    83.38                                   81.75
# 1                    82.02                                   76.74
# 2                    83.13                                   78.19
# 3                    82.30                                   77.40
# 4                    79.70                                   78.26
#
#    accurate_short_medium_pass_percent  accurate_smart_passes_percent  \
# ...

# %%
full_dataframe.shape
# Out:
# (8070, 111)

# %%
full_dataframe.to_csv('wyscout_continente_americano.csv', index=False)

# %%
jugadores_full = pd.read_csv('wyscout_continente_americano.csv')
jugadores_full.head(10)
# Out:
#    index  accurate_crosses_percent  accurate_pass_to_penalty_area_percent  \
# 0      0                     28.57                                  59.83
# 1      1                     22.62                                  59.09
# 2      2                     24.24                                  45.90
# 3      3                     23.26                                  57.14
# 4      4                     52.94                                  56.25
# 5      5                     38.33                                  63.38
# 6      6                     28.57                                  50.86
# 7      7                     31.58                                  46.39
# 8      8                     42.86                                  63.64
# 9      9                     17.39                                  47.22
#
#    accurate_passes_percent  accurate_passes_to_final_third_percent  \
# 0                    83.38                                   81.75
# ...

# %% [markdown]
# Todos los índices van de o a 30 y vuelven a empezar - eliminarlos.
